# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer
from datasets import Dataset

# %% [markdown]
# ## Load Dataset

# %%
data_path = "../data/jujutsu.jsonl"
df = pd.read_json(data_path, lines=True)
df.head()
# Out:
#                           jutsu_name  \
# 0                       10 Hit Combo
# 1             Amenotejikara: Chidori
# 2    Amenosubaruboshinomikoto: Ryūgū
# 3  Amplification Summoning Technique
# 4             Amenotejikara: Instant
#
#                                           jutsu_type  \
# 0                                           Taijutsu
# 1    Kekkei Genkai, Ninjutsu, Dōjutsu, Shurikenjutsu
# 2                                           Ninjutsu
# 3                      Ninjutsu, Space–Time Ninjutsu
# 4  Kekkei Genkai, Ninjutsu, Dōjutsu, Kenjutsu, Sp...
#
#                                    jutsu_description
# 0  Lars punches the opponent before striking them...
# 1  Sasuke throws some lightning infused kunai at ...
# 2  The user extends their arm outward at the targ...
# 3  This is a summoning technique that bestows a s...
# 4  Sasuke attacks his opponent with sword slashes...

# %%
def simplify_jutsu(jutsu):
    if "Genjutsu" in jutsu:
        return "Genjutsu"
    if "Ninjutsu" in jutsu:
        return "Ninjutsu"
    if "Taijutsu" in jutsu:
        return "Taijutsu"

# %%
df["jutsu_type_simplified"] = df["jutsu_type"].apply(simplify_jutsu)

# %%
df.head()
# Out:
#                           jutsu_name  \
# 0                       10 Hit Combo
# 1             Amenotejikara: Chidori
# 2    Amenosubaruboshinomikoto: Ryūgū
# 3  Amplification Summoning Technique
# 4             Amenotejikara: Instant
#
#                                           jutsu_type  \
# 0                                           Taijutsu
# 1    Kekkei Genkai, Ninjutsu, Dōjutsu, Shurikenjutsu
# 2                                           Ninjutsu
# 3                      Ninjutsu, Space–Time Ninjutsu
# 4  Kekkei Genkai, Ninjutsu, Dōjutsu, Kenjutsu, Sp...
#
#                                    jutsu_description jutsu_type_simplified
# 0  Lars punches the opponent before striking them...              Taijutsu
# 1  Sasuke throws some lightning infused kunai at ...              Ninjutsu
# 2  The user extends their arm outward at the targ...              Ninjutsu
# 3  This is a summoning technique that bestows a s...              Ninjutsu
# 4  Sasuke attacks his opponent with sword slashes...              Ninjutsu

# %%
df["jutsu_type_simplified"].value_counts()
# Out:
# jutsu_type_simplified
# Ninjutsu    2263
# Taijutsu     398
# Genjutsu     101
# Name: count, dtype: int64

# %%
df['text'] = df['jutsu_name'] + " " + df['jutsu_description']
df['jutsus'] = df['jutsu_type_simplified']
df =df[["text", "jutsus"]]
df =df.dropna()

# %%
df.head()
# Out:
#                                                 text    jutsus
# 0  10 Hit Combo Lars punches the opponent before ...  Taijutsu
# 1  Amenotejikara: Chidori Sasuke throws some ligh...  Ninjutsu
# 2  Amenosubaruboshinomikoto: Ryūgū The user exten...  Ninjutsu
# 3  Amplification Summoning Technique This is a su...  Ninjutsu
# 4  Amenotejikara: Instant Sasuke attacks his oppo...  Ninjutsu

# %%
from bs4 import BeautifulSoup
class Cleaner():
    def __init__(self):
        pass
    def put_line_breaks(self, text):
        return text.replace("<\p>", "<\p>\n")
    def remove_html_tags(self, text):
        clean_text = BeautifulSoup(text, "lxml").text
        return clean_text
    def clean(self, text):
        text = self.put_line_breaks(text)
        text = self.remove_html_tags(text)
        text = text.strip()
        return text

# %%
text_column_name = 'text'
label_column_name = 'jutsus'

# %%
cleaner = Cleaner()
df['text_cleaned'] = df[text_column_name].apply(cleaner.clean)
# Out:
# C:\Users\kouti\AppData\Local\Temp\ipykernel_24932\1381151371.py:8: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_text = BeautifulSoup(text, "lxml").text

# %%
df.head()
# Out:
#                                                 text    jutsus  \
# 0  10 Hit Combo Lars punches the opponent before ...  Taijutsu
# 1  Amenotejikara: Chidori Sasuke throws some ligh...  Ninjutsu
# 2  Amenosubaruboshinomikoto: Ryūgū The user exten...  Ninjutsu
# 3  Amplification Summoning Technique This is a su...  Ninjutsu
# 4  Amenotejikara: Instant Sasuke attacks his oppo...  Ninjutsu
#
#                                         text_cleaned
# 0  10 Hit Combo Lars punches the opponent before ...
# 1  Amenotejikara: Chidori Sasuke throws some ligh...
# 2  Amenosubaruboshinomikoto: Ryūgū The user exten...
# 3  Amplification Summoning Technique This is a su...
# 4  Amenotejikara: Instant Sasuke attacks his oppo...

# %% [markdown]
# ### Encoding the labels for jutsus column

# %%
le = preprocessing.LabelEncoder()
le.fit(df[label_column_name].tolist())
# Out:
# LabelEncoder()

# %%
label_dict = {index:label_name for index, label_name in enumerate(le.__dict__['classes_'].tolist())}

# %%
label_dict
# Out:
# {0: 'Genjutsu', 1: 'Ninjutsu', 2: 'Taijutsu'}

# %%
df['label'] = le.transform(df[label_column_name].tolist())

# %%
df.head()
# Out:
#                                                 text    jutsus  \
# 0  10 Hit Combo Lars punches the opponent before ...  Taijutsu
# 1  Amenotejikara: Chidori Sasuke throws some ligh...  Ninjutsu
# 2  Amenosubaruboshinomikoto: Ryūgū The user exten...  Ninjutsu
# 3  Amplification Summoning Technique This is a su...  Ninjutsu
# 4  Amenotejikara: Instant Sasuke attacks his oppo...  Ninjutsu
#
#                                         text_cleaned  label
# 0  10 Hit Combo Lars punches the opponent before ...      2
# 1  Amenotejikara: Chidori Sasuke throws some ligh...      1
# 2  Amenosubaruboshinomikoto: Ryūgū The user exten...      1
# 3  Amplification Summoning Technique This is a su...      1
# 4  Amenotejikara: Instant Sasuke attacks his oppo...      1

# %%
### Splitting the data into training and testing data
test_size = 0.2
df_train, df_test = train_test_split(df, 
                                                    test_size=test_size,
                                                    stratify = df['label'],
                                                    )

# %%
### Model Building
model_name = "distilbert/distilbert-base-uncased"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# c:\Users\kouti\OneDrive\Desktop\Naruto_NLP\nlp_env\Lib\site-packages\huggingface_hub\file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\kouti\OneDrive\Desktop\Naruto_NLP\nlp_env\Lib\site-packages\huggingface_hub\file_download.py:147: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\kouti\.cache\huggingface\hub\models--distilbert--distilbert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
def preprocess_function(tokenizer, examples):
    return tokenizer(examples['text_cleaned'], truncation=True)

# %%
# Convert Pandas Dataframe to Hugging Face Dataset
train_dataset = Dataset.from_pandas(df_train)
test_dataset = Dataset.from_pandas(df_test)

# Tokenize the dataset
tokenized_train = train_dataset.map(lambda examples: preprocess_function(tokenizer, examples), batched=True)
tokenized_test = test_dataset.map(lambda examples: preprocess_function(tokenizer, examples), batched=True)
# Out:
# Map: 100%|██████████| 2209/2209 [00:00<00:00, 9160.93 examples/s]
# Map: 100%|██████████| 553/553 [00:00<00:00, 10029.14 examples/s]
